# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle
import tensorflow as tf
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
data_ED = 'drive/MyDrive/CMRI/training ES/'

# %%
os.listdir(data_ED)
# Out:
# ['dataset', 'train.pickle', 'val.pickle']

# %% [markdown]
# # Load Pickle File

# %%
with open(os.path.join(data_ED, 'train.pickle'), 'rb') as f:
  train_data = pickle.load(f)
  del train_data['y_processed']

with open(os.path.join(data_ED, 'val.pickle'), 'rb') as f:
  val_data = pickle.load(f)
  del val_data['y_processed']

# %%
train_data['x'].shape, train_data['y'].shape
# Out:
# ((763, 256, 256), (763, 256, 256))

# %% [markdown]
# # Visualization

# %%
def highlight_classes(image, mask):
    # Define colors for each class
    class_colors = {
        1: 0,    # Right Ventricle
        2: 127.5,    # Myocardium
        3: 255,    # Left Ventricle
    }

    # convert mask labels to integer
    mask = mask.astype(int)

    # Create a new image for visualization
    visualized_image = np.copy(image)

    # Loop through each pixel in the mask
    for row in range(mask.shape[0]):
        for col in range(mask.shape[1]):
            pixel_class = mask[row, col]

            # Check if the pixel class is 0-2
            if pixel_class in class_colors.keys():
                # Get the corresponding color for the class
                color = class_colors[pixel_class]

                # Highlight the pixel in the visualized image
                visualized_image[row, col] = color

    return visualized_image

# %%
# Load your image and mask
idx = 5
image = train_data['x'][idx]
mask = train_data['y'][idx]

# Call the function to generate the highlighted image
highlighted_image = highlight_classes(image, mask)

# Display highlighted image
plt.imshow(highlighted_image, cmap='gray')
plt.title("Highlighted Image")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocess Input

# %%
train_data['x'] = np.expand_dims(train_data['x'], -1)
val_data['x'] = np.expand_dims(val_data['x'], -1)
train_data['y'] = np.expand_dims(train_data['y'], -1)
val_data['y'] = np.expand_dims(val_data['y'], -1)

# %%
train_data['x'].shape, train_data['y'].shape
# Out:
# ((763, 256, 256, 1), (763, 256, 256, 1))

# %% [markdown]
# # Build UNET Architecture

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Conv2DTranspose, Concatenate

def unet(input_shape, input_channels, num_classes):
    inputs = Input(shape=(input_shape[0], input_shape[1], input_channels))

    # Encoder path
    conv1 = Conv2D(16, 3, activation='relu', padding='same')(inputs)
    conv2 = Conv2D(16, 3, activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(16, 3, activation='relu', padding='same')(pool1)
    conv4 = Conv2D(16, 3, activation='relu', padding='same')(conv3)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(32, 3, activation='relu', padding='same')(pool2)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv5)

    conv6 = Conv2D(128, 3, activation='relu', padding='same')(pool3)
    conv7 = Conv2D(128, 3, activation='relu', padding='same')(conv6)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv7)

    # Bottom of the U shape
    fc8 = Conv2D(256, 3, activation='relu', padding='same')(pool4)
    fc9 = Conv2D(128, 3, activation='relu', padding='same')(fc8)
    fc10 = Conv2D(2, 3, activation='softmax', padding='same')(fc9)

    fc11 = Conv2D(2, 3, activation='softmax', padding='same')(fc10)
    fc12 = Conv2D(128, 3, activation='relu', padding='same')(fc11)
    fc13 = Conv2D(256, 3, activation='relu', padding='same')(fc12)

    # Decoder path
    up6 = Conv2DTranspose(128, 2, strides=(2, 2), activation='relu', padding='same')(fc13)
    merge6 = Concatenate()([conv7, up6])
    conv8 = Conv2D(128, 3, activation='relu', padding='same')(merge6)
    conv9 = Conv2D(128, 3, activation='relu', padding='same')(conv8)

    up7 = Conv2DTranspose(32, 2, strides=(2, 2), activation='relu', padding='same')(conv9)
    merge7 = Concatenate()([conv5, up7])
    conv10 = Conv2D(32, 3, activation='relu', padding='same')(merge7)

    up8 = Conv2DTranspose(16, 2, strides=(2, 2), activation='relu', padding='same')(conv10)
    merge8 = Concatenate()([conv4, up8])
    conv11 = Conv2D(16, 3, activation='relu', padding='same')(merge8)
    conv12 = Conv2D(16, 3, activation='relu', padding='same')(conv11)

    up9 = Conv2DTranspose(16, 2, strides=(2, 2), activation='relu', padding='same')(conv12)
    merge9 = Concatenate()([conv2, up9])
    conv13 = Conv2D(16, 3, activation='relu', padding='same')(merge9)
    conv14 = Conv2D(16, 3, activation='relu', padding='same')(conv13)

    # Output layer with the number of classes defined
    outputs = Conv2D(num_classes, 1, activation='softmax')(conv14)

    model = Model(inputs=inputs, outputs=outputs)

    return model

# %%
model = unet((256,256),1,4) #input channel 1 dan output channel nya 4

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 16  160         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  2320        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 16  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 16  2320        ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 16  2320        ['conv2d_2[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 16)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 32)  0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  36992       ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_5[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  295168      ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 128)  295040      ['conv2d_7[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 2)    2306        ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 2)    38          ['conv2d_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  2432        ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 256)  295168      ['conv2d_11[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  131200     ['conv2d_12[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 256)  0           ['conv2d_6[0][0]',
#                                                                   'conv2d_transpose[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_13[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 32)  16416       ['conv2d_14[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_4[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 32)   18464       ['concatenate_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 16  2064       ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_3[0][0]',
#                                 )                                 'conv2d_transpose_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 16  4624        ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 16  2320        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  1040       ['conv2d_17[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 32  0           ['conv2d_1[0][0]',
#                                 )                                 'conv2d_transpose_3[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 16  4624        ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 16  2320        ['conv2d_18[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 4)  68          ['conv2d_19[0][0]']
#
# ==================================================================================================
# Total params: 1,712,252
# Trainable params: 1,712,252
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Modelling

# %%
def preprocess_input(x):
  #Normalize the input values to the range [0,1]
  return x / 255.0

def preprocess_output(y):
  #Convert categorical labels to one-hot encoded masks
  return tf.keras.utils.to_categorical(y, num_classes=4)

def preprocess_output1(y):
    y = tf.cast(y, tf.int32)
    y_onehot = tf.one_hot(y, 4)  # Convert to one-hot encoding
    return y_onehot

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.backend import epsilon

def save_logging(path, text):
  with open(path, 'a') as f:
    f.writelines(text+'\n')

def has_all_zeros(tensor):
    return tf.reduce_all(tensor == 0)

def dice_score_per_class(y_true, y_pred, num_classes=4, sample_weight=None):
    y_true = preprocess_output1(y_true)

    dice_scores = []
    for class_id in range(num_classes):
        y_true_class = tf.keras.backend.flatten(y_true[..., class_id])
        y_pred_class = tf.keras.backend.flatten(y_pred[..., class_id])
        intersection = tf.keras.backend.sum(y_true_class * y_pred_class)
        dice_score = (2.0 * intersection + epsilon()) / (tf.keras.backend.sum(y_true_class) + tf.keras.backend.sum(y_pred_class) + epsilon())
        # if has_all_zeros(y_true_class) and has_all_zeros(y_pred_class):
        #   dice_score = tf.ones(dice_score.shape, dice_score.dtype)
        #   dice_scores.append(dice_score)
        # else:
        #   save_logging('log.txt', str(dice_score))
        dice_scores.append(dice_score)

    dice_scores_tensor = tf.stack(dice_scores)
    return dice_scores_tensor


def dice_coefficient(y_true, y_pred): #dice coefficient butuh one hot encoding yang categorical
    y_true = tf.cast(y_true, tf.int32)
    y_true = preprocess_output1(y_true)
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.keras.backend.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + epsilon()) / (tf.keras.backend.sum(y_true_f) + tf.keras.backend.sum(y_pred_f) + epsilon())

def dice_loss(y_true, y_pred):
    # Define epsilon to prevent division by zero
    epsilon = tf.keras.backend.epsilon()

    # Calculate the sum of y_true and y_pred for each class
    y_true_sum = tf.reduce_sum(y_true, axis=[0, 1, 2])
    y_pred_sum = tf.reduce_sum(y_pred, axis=[0, 1, 2])

    # Calculate the intersection and union of y_true and y_pred
    intersection = tf.reduce_sum(y_true * y_pred, axis=[0, 1, 2])
    union = y_true_sum + y_pred_sum

    # Calculate the Dice coefficient for each class
    dice = (2. * intersection + epsilon) / (union + epsilon)

    # Calculate the weight for each class
    weight = 1. / ((y_true_sum**2) + epsilon)

    # Calculate the generalized Dice loss
    generalized_dice = tf.reduce_sum(weight * dice)
    generalized_dice_loss = 1. - (2. * generalized_dice)

    return generalized_dice_loss

def train_unet(x_train, y_train, x_val, y_val, input_shape, num_classes, batch_size, epochs):
    # Preprocess the training and validation data
    x_train = preprocess_input(x_train)
    x_val = preprocess_input(x_val)

    # y_train = preprocess_output(y_train)
    # y_val = preprocess_output(y_val)

    print(y_train.shape, y_train.dtype)

    # Create and compile the U-Net model
    model = unet(input_shape, input_channels=1, num_classes=num_classes)
    model.compile(optimizer=Adam(learning_rate=1e-4),
                  loss=SparseCategoricalCrossentropy(),
                  metrics=['accuracy',dice_coefficient])

    # Add Early Stopping callback
    early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
    checkpoint = ModelCheckpoint(filepath="cmri_unet2D_mod.h5", monitor="val_loss", mode="min", save_best_only=True, verbose=1)

    # # Train the model
    # model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
    #           validation_data=(x_val, y_val), callbacks=[early_stopping])

    # for epoch in range(epochs):
    #     model.fit(x_train, y_train, batch_size=batch_size, epochs=1,
    #               validation_data=(x_val, y_val), callbacks=[early_stopping, checkpoint])


    #         # Get the dice scores per class from the dice_metric
    #     dice_scores_per_class = dice_score_per_class(y_true=y_val, y_pred=model.predict(x_val))

    #     # Convert dice scores to a more readable format
    #     formatted_dice_scores = [f"{score:.4f}" for score in dice_scores_per_class.numpy()]

    #     # Print the dice scores per class
    #     print(f"Epoch {epoch+1}: Dice Scores per Class: {formatted_dice_scores}")

    # Train the model
    model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs,
              validation_data=(x_val, y_val), callbacks=[early_stopping,checkpoint])

    return model

# %% [markdown]
# Kalau loss-nya turun berarti it works

# %%
model = train_unet(train_data['x'], train_data['y'], val_data['x'], val_data['y'], (256,256), 4, 8, 200)
# Out:
# (763, 256, 256, 1) float64
# Epoch 1/200
# 96/96 [==============================] - ETA: 0s - loss: 1.1112 - accuracy: 0.8041 - dice_coefficient: 0.4081
# Epoch 1: val_loss improved from inf to 0.28396, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 28s 81ms/step - loss: 1.1112 - accuracy: 0.8041 - dice_coefficient: 0.4081 - val_loss: 0.2840 - val_accuracy: 0.9706 - val_dice_coefficient: 0.8548
# Epoch 2/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.2389 - accuracy: 0.9670 - dice_coefficient: 0.9046
# Epoch 2: val_loss improved from 0.28396 to 0.16314, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 5s 56ms/step - loss: 0.2384 - accuracy: 0.9671 - dice_coefficient: 0.9050 - val_loss: 0.1631 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9290
# Epoch 3/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.1590 - accuracy: 0.9670 - dice_coefficient: 0.9345
# Epoch 3: val_loss improved from 0.16314 to 0.12938, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 5s 57ms/step - loss: 0.1587 - accuracy: 0.9671 - dice_coefficient: 0.9347 - val_loss: 0.1294 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9386
# Epoch 4/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.1297 - accuracy: 0.9671 - dice_coefficient: 0.9430
# Epoch 4: val_loss improved from 0.12938 to 0.11645, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 5s 57ms/step - loss: 0.1297 - accuracy: 0.9671 - dice_coefficient: 0.9430 - val_loss: 0.1165 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9345
# Epoch 5/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.1151 - accuracy: 0.9670 - dice_coefficient: 0.9466
# Epoch 5: val_loss improved from 0.11645 to 0.09785, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 5s 57ms/step - loss: 0.1149 - accuracy: 0.9671 - dice_coefficient: 0.9467 - val_loss: 0.0978 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9466
# Epoch 6/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.1051 - accuracy: 0.9671 - dice_coefficient: 0.9499
# Epoch 6: val_loss improved from 0.09785 to 0.09363, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 5s 57ms/step - loss: 0.1052 - accuracy: 0.9671 - dice_coefficient: 0.9498 - val_loss: 0.0936 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9500
# Epoch 7/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0958 - accuracy: 0.9670 - dice_coefficient: 0.9533
# Epoch 7: val_loss improved from 0.09363 to 0.08593, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 57ms/step - loss: 0.0957 - accuracy: 0.9671 - dice_coefficient: 0.9535 - val_loss: 0.0859 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9523
# Epoch 8/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0950 - accuracy: 0.9670 - dice_coefficient: 0.9530
# Epoch 8: val_loss did not improve from 0.08593
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0949 - accuracy: 0.9671 - dice_coefficient: 0.9532 - val_loss: 0.0957 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9630
# Epoch 9/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0976 - accuracy: 0.9671 - dice_coefficient: 0.9524
# Epoch 9: val_loss improved from 0.08593 to 0.08539, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0979 - accuracy: 0.9671 - dice_coefficient: 0.9523 - val_loss: 0.0854 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9593
# Epoch 10/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0931 - accuracy: 0.9671 - dice_coefficient: 0.9540
# Epoch 10: val_loss improved from 0.08539 to 0.07975, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0931 - accuracy: 0.9671 - dice_coefficient: 0.9540 - val_loss: 0.0797 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9608
# Epoch 11/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0873 - accuracy: 0.9671 - dice_coefficient: 0.9563
# Epoch 11: val_loss did not improve from 0.07975
# 96/96 [==============================] - 5s 56ms/step - loss: 0.0873 - accuracy: 0.9671 - dice_coefficient: 0.9564 - val_loss: 0.0839 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9654
# Epoch 12/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0862 - accuracy: 0.9671 - dice_coefficient: 0.9568
# Epoch 12: val_loss improved from 0.07975 to 0.07661, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0862 - accuracy: 0.9671 - dice_coefficient: 0.9569 - val_loss: 0.0766 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9601
# Epoch 13/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9670 - dice_coefficient: 0.9573
# Epoch 13: val_loss improved from 0.07661 to 0.07471, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0844 - accuracy: 0.9671 - dice_coefficient: 0.9574 - val_loss: 0.0747 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9629
# Epoch 14/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0812 - accuracy: 0.9671 - dice_coefficient: 0.9589
# Epoch 14: val_loss did not improve from 0.07471
# 96/96 [==============================] - 5s 57ms/step - loss: 0.0813 - accuracy: 0.9671 - dice_coefficient: 0.9588 - val_loss: 0.0773 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9549
# Epoch 15/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0782 - accuracy: 0.9671 - dice_coefficient: 0.9598
# Epoch 15: val_loss did not improve from 0.07471
# 96/96 [==============================] - 5s 57ms/step - loss: 0.0783 - accuracy: 0.9671 - dice_coefficient: 0.9598 - val_loss: 0.0753 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9567
# Epoch 16/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0760 - accuracy: 0.9671 - dice_coefficient: 0.9609
# Epoch 16: val_loss did not improve from 0.07471
# 96/96 [==============================] - 5s 57ms/step - loss: 0.0760 - accuracy: 0.9671 - dice_coefficient: 0.9608 - val_loss: 0.0754 - val_accuracy: 0.9706 - val_dice_coefficient: 0.9548
# Epoch 17/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0736 - accuracy: 0.9673 - dice_coefficient: 0.9619
# Epoch 17: val_loss improved from 0.07471 to 0.07341, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0736 - accuracy: 0.9673 - dice_coefficient: 0.9618 - val_loss: 0.0734 - val_accuracy: 0.9711 - val_dice_coefficient: 0.9626
# Epoch 18/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0819 - accuracy: 0.9683 - dice_coefficient: 0.9585
# Epoch 18: val_loss did not improve from 0.07341
# 96/96 [==============================] - 5s 57ms/step - loss: 0.0819 - accuracy: 0.9684 - dice_coefficient: 0.9586 - val_loss: 0.0754 - val_accuracy: 0.9737 - val_dice_coefficient: 0.9553
# Epoch 19/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0753 - accuracy: 0.9714 - dice_coefficient: 0.9611
# Epoch 19: val_loss improved from 0.07341 to 0.07064, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0753 - accuracy: 0.9714 - dice_coefficient: 0.9611 - val_loss: 0.0706 - val_accuracy: 0.9752 - val_dice_coefficient: 0.9590
# Epoch 20/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0731 - accuracy: 0.9733 - dice_coefficient: 0.9620
# Epoch 20: val_loss did not improve from 0.07064
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0732 - accuracy: 0.9733 - dice_coefficient: 0.9619 - val_loss: 0.0713 - val_accuracy: 0.9764 - val_dice_coefficient: 0.9577
# Epoch 21/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0703 - accuracy: 0.9750 - dice_coefficient: 0.9632
# Epoch 21: val_loss improved from 0.07064 to 0.06394, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0704 - accuracy: 0.9750 - dice_coefficient: 0.9632 - val_loss: 0.0639 - val_accuracy: 0.9781 - val_dice_coefficient: 0.9644
# Epoch 22/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0675 - accuracy: 0.9761 - dice_coefficient: 0.9645
# Epoch 22: val_loss improved from 0.06394 to 0.06387, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0675 - accuracy: 0.9761 - dice_coefficient: 0.9645 - val_loss: 0.0639 - val_accuracy: 0.9789 - val_dice_coefficient: 0.9629
# Epoch 23/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0640 - accuracy: 0.9774 - dice_coefficient: 0.9662
# Epoch 23: val_loss improved from 0.06387 to 0.05871, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0641 - accuracy: 0.9773 - dice_coefficient: 0.9661 - val_loss: 0.0587 - val_accuracy: 0.9795 - val_dice_coefficient: 0.9676
# Epoch 24/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0613 - accuracy: 0.9781 - dice_coefficient: 0.9676
# Epoch 24: val_loss did not improve from 0.05871
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0614 - accuracy: 0.9781 - dice_coefficient: 0.9676 - val_loss: 0.0608 - val_accuracy: 0.9784 - val_dice_coefficient: 0.9708
# Epoch 25/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0577 - accuracy: 0.9789 - dice_coefficient: 0.9694
# Epoch 25: val_loss improved from 0.05871 to 0.05489, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0577 - accuracy: 0.9789 - dice_coefficient: 0.9694 - val_loss: 0.0549 - val_accuracy: 0.9804 - val_dice_coefficient: 0.9683
# Epoch 26/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0544 - accuracy: 0.9796 - dice_coefficient: 0.9708
# Epoch 26: val_loss did not improve from 0.05489
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0544 - accuracy: 0.9796 - dice_coefficient: 0.9709 - val_loss: 0.0583 - val_accuracy: 0.9794 - val_dice_coefficient: 0.9649
# Epoch 27/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0537 - accuracy: 0.9797 - dice_coefficient: 0.9711
# Epoch 27: val_loss improved from 0.05489 to 0.04951, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0538 - accuracy: 0.9797 - dice_coefficient: 0.9711 - val_loss: 0.0495 - val_accuracy: 0.9822 - val_dice_coefficient: 0.9730
# Epoch 28/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0513 - accuracy: 0.9804 - dice_coefficient: 0.9723
# Epoch 28: val_loss did not improve from 0.04951
# 96/96 [==============================] - 6s 58ms/step - loss: 0.0514 - accuracy: 0.9804 - dice_coefficient: 0.9721 - val_loss: 0.0500 - val_accuracy: 0.9821 - val_dice_coefficient: 0.9703
# Epoch 29/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0490 - accuracy: 0.9813 - dice_coefficient: 0.9732
# Epoch 29: val_loss improved from 0.04951 to 0.04633, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0490 - accuracy: 0.9813 - dice_coefficient: 0.9733 - val_loss: 0.0463 - val_accuracy: 0.9828 - val_dice_coefficient: 0.9743
# Epoch 30/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0485 - accuracy: 0.9816 - dice_coefficient: 0.9735
# Epoch 30: val_loss improved from 0.04633 to 0.04569, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0485 - accuracy: 0.9816 - dice_coefficient: 0.9736 - val_loss: 0.0457 - val_accuracy: 0.9834 - val_dice_coefficient: 0.9747
# Epoch 31/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0470 - accuracy: 0.9825 - dice_coefficient: 0.9743
# Epoch 31: val_loss did not improve from 0.04569
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0470 - accuracy: 0.9825 - dice_coefficient: 0.9743 - val_loss: 0.0465 - val_accuracy: 0.9831 - val_dice_coefficient: 0.9745
# Epoch 32/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0460 - accuracy: 0.9828 - dice_coefficient: 0.9747
# Epoch 32: val_loss improved from 0.04569 to 0.04310, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0460 - accuracy: 0.9828 - dice_coefficient: 0.9747 - val_loss: 0.0431 - val_accuracy: 0.9839 - val_dice_coefficient: 0.9766
# Epoch 33/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0440 - accuracy: 0.9836 - dice_coefficient: 0.9758
# Epoch 33: val_loss did not improve from 0.04310
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0440 - accuracy: 0.9836 - dice_coefficient: 0.9757 - val_loss: 0.0452 - val_accuracy: 0.9838 - val_dice_coefficient: 0.9732
# Epoch 34/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0445 - accuracy: 0.9835 - dice_coefficient: 0.9757
# Epoch 34: val_loss did not improve from 0.04310
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0445 - accuracy: 0.9835 - dice_coefficient: 0.9758 - val_loss: 0.0434 - val_accuracy: 0.9842 - val_dice_coefficient: 0.9772
# Epoch 35/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0425 - accuracy: 0.9843 - dice_coefficient: 0.9764
# Epoch 35: val_loss did not improve from 0.04310
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0425 - accuracy: 0.9843 - dice_coefficient: 0.9765 - val_loss: 0.0437 - val_accuracy: 0.9835 - val_dice_coefficient: 0.9749
# Epoch 36/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0415 - accuracy: 0.9846 - dice_coefficient: 0.9771
# Epoch 36: val_loss improved from 0.04310 to 0.04079, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0415 - accuracy: 0.9846 - dice_coefficient: 0.9771 - val_loss: 0.0408 - val_accuracy: 0.9849 - val_dice_coefficient: 0.9788
# Epoch 37/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0394 - accuracy: 0.9855 - dice_coefficient: 0.9781
# Epoch 37: val_loss did not improve from 0.04079
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0394 - accuracy: 0.9854 - dice_coefficient: 0.9781 - val_loss: 0.0440 - val_accuracy: 0.9836 - val_dice_coefficient: 0.9730
# Epoch 38/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0390 - accuracy: 0.9857 - dice_coefficient: 0.9784
# Epoch 38: val_loss did not improve from 0.04079
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0390 - accuracy: 0.9857 - dice_coefficient: 0.9784 - val_loss: 0.0453 - val_accuracy: 0.9833 - val_dice_coefficient: 0.9728
# Epoch 39/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0387 - accuracy: 0.9856 - dice_coefficient: 0.9785
# Epoch 39: val_loss improved from 0.04079 to 0.03985, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0387 - accuracy: 0.9857 - dice_coefficient: 0.9785 - val_loss: 0.0399 - val_accuracy: 0.9852 - val_dice_coefficient: 0.9776
# Epoch 40/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0369 - accuracy: 0.9865 - dice_coefficient: 0.9794
# Epoch 40: val_loss did not improve from 0.03985
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0369 - accuracy: 0.9865 - dice_coefficient: 0.9794 - val_loss: 0.0413 - val_accuracy: 0.9843 - val_dice_coefficient: 0.9760
# Epoch 41/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0359 - accuracy: 0.9869 - dice_coefficient: 0.9799
# Epoch 41: val_loss improved from 0.03985 to 0.03797, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0359 - accuracy: 0.9869 - dice_coefficient: 0.9799 - val_loss: 0.0380 - val_accuracy: 0.9859 - val_dice_coefficient: 0.9795
# Epoch 42/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0352 - accuracy: 0.9870 - dice_coefficient: 0.9804
# Epoch 42: val_loss did not improve from 0.03797
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0352 - accuracy: 0.9870 - dice_coefficient: 0.9804 - val_loss: 0.0388 - val_accuracy: 0.9857 - val_dice_coefficient: 0.9776
# Epoch 43/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0344 - accuracy: 0.9875 - dice_coefficient: 0.9808
# Epoch 43: val_loss did not improve from 0.03797
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0344 - accuracy: 0.9875 - dice_coefficient: 0.9807 - val_loss: 0.0408 - val_accuracy: 0.9843 - val_dice_coefficient: 0.9755
# Epoch 44/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0339 - accuracy: 0.9877 - dice_coefficient: 0.9811
# Epoch 44: val_loss improved from 0.03797 to 0.03424, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0339 - accuracy: 0.9876 - dice_coefficient: 0.9810 - val_loss: 0.0342 - val_accuracy: 0.9871 - val_dice_coefficient: 0.9812
# Epoch 45/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0330 - accuracy: 0.9879 - dice_coefficient: 0.9815
# Epoch 45: val_loss did not improve from 0.03424
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0330 - accuracy: 0.9879 - dice_coefficient: 0.9816 - val_loss: 0.0388 - val_accuracy: 0.9852 - val_dice_coefficient: 0.9782
# Epoch 46/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0313 - accuracy: 0.9885 - dice_coefficient: 0.9822
# Epoch 46: val_loss improved from 0.03424 to 0.03334, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0313 - accuracy: 0.9885 - dice_coefficient: 0.9822 - val_loss: 0.0333 - val_accuracy: 0.9875 - val_dice_coefficient: 0.9827
# Epoch 47/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0310 - accuracy: 0.9887 - dice_coefficient: 0.9826
# Epoch 47: val_loss did not improve from 0.03334
# 96/96 [==============================] - 6s 59ms/step - loss: 0.0311 - accuracy: 0.9886 - dice_coefficient: 0.9826 - val_loss: 0.0342 - val_accuracy: 0.9873 - val_dice_coefficient: 0.9817
# Epoch 48/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0324 - accuracy: 0.9880 - dice_coefficient: 0.9820
# Epoch 48: val_loss improved from 0.03334 to 0.03317, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0324 - accuracy: 0.9880 - dice_coefficient: 0.9820 - val_loss: 0.0332 - val_accuracy: 0.9876 - val_dice_coefficient: 0.9822
# Epoch 49/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0297 - accuracy: 0.9890 - dice_coefficient: 0.9832
# Epoch 49: val_loss did not improve from 0.03317
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0297 - accuracy: 0.9890 - dice_coefficient: 0.9832 - val_loss: 0.0333 - val_accuracy: 0.9877 - val_dice_coefficient: 0.9810
# Epoch 50/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0284 - accuracy: 0.9895 - dice_coefficient: 0.9838
# Epoch 50: val_loss did not improve from 0.03317
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0283 - accuracy: 0.9895 - dice_coefficient: 0.9839 - val_loss: 0.0334 - val_accuracy: 0.9875 - val_dice_coefficient: 0.9817
# Epoch 51/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0282 - accuracy: 0.9896 - dice_coefficient: 0.9841
# Epoch 51: val_loss did not improve from 0.03317
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0282 - accuracy: 0.9896 - dice_coefficient: 0.9841 - val_loss: 0.0338 - val_accuracy: 0.9872 - val_dice_coefficient: 0.9818
# Epoch 52/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0285 - accuracy: 0.9894 - dice_coefficient: 0.9840
# Epoch 52: val_loss did not improve from 0.03317
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0285 - accuracy: 0.9894 - dice_coefficient: 0.9840 - val_loss: 0.0337 - val_accuracy: 0.9873 - val_dice_coefficient: 0.9819
# Epoch 53/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0289 - accuracy: 0.9892 - dice_coefficient: 0.9839
# Epoch 53: val_loss improved from 0.03317 to 0.03243, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 61ms/step - loss: 0.0289 - accuracy: 0.9893 - dice_coefficient: 0.9839 - val_loss: 0.0324 - val_accuracy: 0.9880 - val_dice_coefficient: 0.9833
# Epoch 54/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0259 - accuracy: 0.9905 - dice_coefficient: 0.9852
# Epoch 54: val_loss did not improve from 0.03243
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0259 - accuracy: 0.9905 - dice_coefficient: 0.9852 - val_loss: 0.0332 - val_accuracy: 0.9874 - val_dice_coefficient: 0.9823
# Epoch 55/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0255 - accuracy: 0.9904 - dice_coefficient: 0.9855
# Epoch 55: val_loss did not improve from 0.03243
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0256 - accuracy: 0.9904 - dice_coefficient: 0.9854 - val_loss: 0.0334 - val_accuracy: 0.9877 - val_dice_coefficient: 0.9829
# Epoch 56/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0264 - accuracy: 0.9902 - dice_coefficient: 0.9852
# Epoch 56: val_loss did not improve from 0.03243
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0264 - accuracy: 0.9902 - dice_coefficient: 0.9851 - val_loss: 0.0382 - val_accuracy: 0.9851 - val_dice_coefficient: 0.9789
# Epoch 57/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9905 - dice_coefficient: 0.9856
# Epoch 57: val_loss improved from 0.03243 to 0.03196, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 62ms/step - loss: 0.0254 - accuracy: 0.9905 - dice_coefficient: 0.9856 - val_loss: 0.0320 - val_accuracy: 0.9880 - val_dice_coefficient: 0.9834
# Epoch 58/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0253 - accuracy: 0.9906 - dice_coefficient: 0.9857
# Epoch 58: val_loss did not improve from 0.03196
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0253 - accuracy: 0.9906 - dice_coefficient: 0.9857 - val_loss: 0.0326 - val_accuracy: 0.9881 - val_dice_coefficient: 0.9837
# Epoch 59/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0251 - accuracy: 0.9905 - dice_coefficient: 0.9858
# Epoch 59: val_loss did not improve from 0.03196
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0251 - accuracy: 0.9905 - dice_coefficient: 0.9858 - val_loss: 0.0329 - val_accuracy: 0.9879 - val_dice_coefficient: 0.9836
# Epoch 60/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0233 - accuracy: 0.9913 - dice_coefficient: 0.9867
# Epoch 60: val_loss did not improve from 0.03196
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0233 - accuracy: 0.9913 - dice_coefficient: 0.9867 - val_loss: 0.0367 - val_accuracy: 0.9860 - val_dice_coefficient: 0.9807
# Epoch 61/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9912 - dice_coefficient: 0.9868
# Epoch 61: val_loss did not improve from 0.03196
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0235 - accuracy: 0.9912 - dice_coefficient: 0.9867 - val_loss: 0.0334 - val_accuracy: 0.9875 - val_dice_coefficient: 0.9831
# Epoch 62/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0236 - accuracy: 0.9912 - dice_coefficient: 0.9866
# Epoch 62: val_loss improved from 0.03196 to 0.02983, saving model to cmri_unet2D_mod.h5
# 96/96 [==============================] - 6s 62ms/step - loss: 0.0236 - accuracy: 0.9912 - dice_coefficient: 0.9866 - val_loss: 0.0298 - val_accuracy: 0.9889 - val_dice_coefficient: 0.9850
# Epoch 63/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0224 - accuracy: 0.9916 - dice_coefficient: 0.9873
# Epoch 63: val_loss did not improve from 0.02983
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0224 - accuracy: 0.9916 - dice_coefficient: 0.9873 - val_loss: 0.0347 - val_accuracy: 0.9868 - val_dice_coefficient: 0.9822
# Epoch 64/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0230 - accuracy: 0.9914 - dice_coefficient: 0.9872
# Epoch 64: val_loss did not improve from 0.02983
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0230 - accuracy: 0.9914 - dice_coefficient: 0.9872 - val_loss: 0.0511 - val_accuracy: 0.9807 - val_dice_coefficient: 0.9758
# Epoch 65/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0234 - accuracy: 0.9912 - dice_coefficient: 0.9868
# Epoch 65: val_loss did not improve from 0.02983
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0234 - accuracy: 0.9912 - dice_coefficient: 0.9868 - val_loss: 0.0309 - val_accuracy: 0.9888 - val_dice_coefficient: 0.9854
# Epoch 66/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0214 - accuracy: 0.9920 - dice_coefficient: 0.9878
# Epoch 66: val_loss did not improve from 0.02983
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0214 - accuracy: 0.9920 - dice_coefficient: 0.9878 - val_loss: 0.0315 - val_accuracy: 0.9879 - val_dice_coefficient: 0.9834
# Epoch 67/200
# 95/96 [============================>.] - ETA: 0s - loss: 0.0207 - accuracy: 0.9922 - dice_coefficient: 0.9881
# Epoch 67: val_loss did not improve from 0.02983
# 96/96 [==============================] - 6s 60ms/step - loss: 0.0207 - accuracy: 0.9922 - dice_coefficient: 0.9881 - val_loss: 0.0308 - val_accuracy: 0.9889 - val_dice_coefficient: 0.9854

# %%
sample = val_data['x'][:10]
sample_label = val_data['y'][:10]
sample = preprocess_input(sample)
result = model.predict(sample)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
result.shape
# Out:
# (10, 256, 256, 4)

# %%
def postprocess_output(one_hot_output):
    # Find the class index with the highest probability for each pixel
    categorical_output = np.argmax(one_hot_output, axis=-1)

    return categorical_output

# %%
out = postprocess_output(result)
out.shape
# Out:
# (10, 256, 256)

# %%
import matplotlib.pyplot as plt

for s, o, gt in zip(sample, out, sample_label):
  print('sample input')
  s = np.squeeze(s)
  plt.imshow(s)
  plt.show()
  gt = np.squeeze(gt)
  print('prediction')
  plt.imshow(o)
  plt.show()
  print('groundtruth')
  plt.imshow(gt)
  plt.show()
# Out:
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth
# sample input
# prediction
# groundtruth

# %%
from keras.utils import to_categorical

# %%
from keras.models import load_model
import random

# %%
x_test = np.expand_dims(val_data['x'] / 255, -1)
y_test = to_categorical(val_data['y'], num_classes=4)

# %%
y_pred = model.predict(val_data['x'])
# Out:
# 7/7 [==============================] - 2s 45ms/step

# %%
# Generate random index from testing set
idx = random.randint(0, len(y_pred) - 1)
# Load your image and mask
image = np.squeeze(x_test[idx] * 255)
pred = np.argmax(y_pred[idx], axis=2)
label = np.argmax(y_test[idx], axis=2)

# Call the function to generate the highlighted image
ground_truth = highlight_classes(image, label)
prediction = highlight_classes(image, pred)

# Display highlighted image
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(image, cmap='gray')
plt.title("CMRI Image")

plt.subplot(1, 3, 2)
plt.imshow(ground_truth, cmap='gray')
plt.title("Ground Truth")

plt.subplot(1, 3, 3)
plt.imshow(prediction, cmap='gray')
plt.title("Prediction")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Inference Time

# %%
model.save('trained_unet_model_modif.h5')

# %%
import time

# Preprocess the validation data
sample = val_data['x']
sample_label = val_data['y']
x_val_processed = preprocess_input(sample)

# Measure inference time for the entire validation dataset
start_time = time.time()
predictions = model.predict(x_val_processed)
end_time = time.time()

inference_time = end_time - start_time
print(f"Total Inference Time for Validation Set: {inference_time:.4f} seconds")
# Out:
# 7/7 [==============================] - 0s 52ms/step
# Total Inference Time for Validation Set: 0.6901 seconds
